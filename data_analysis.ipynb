# %% [markdown]
# # Preliminaries

# %% [markdown]
# # About python package
# 检查一下pip是否正确安装
# ```bash
# pip --version
# ```
# 有关pip管理package的操作
# 检查目前环境下所有的package:
# ```bash
# pip list
# ```
# 检查是否安装了特定的package:
# ```bash
# pip show < PACKAGE_NAME >
# ```
# 安装特定的的package:
# ```bash
# pip install < PACKAGE_NAME >
# ```

# %% [markdown]
# # Basic data analysis
